# %% [markdown]
# + The PDF stands for Portable DOcument Format and it uses .pdf file extension. To read the pdf PyPDF2 module is used.
# + PyPDF2 does not have a way to extract images, charts, or other media from PDF documents, but it can extract text and return it as a Python string.

# %%
  import PyPDF2
pdfFileObj = open("D:/C_Band_Silkheds_Docs/1EF48_2E.pdf","rb")
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)

# %%
pdfReader.numPages
# Out:
# 12

# %%
pageobj = pdfReader.getPage(1)

# %%
pageobj.extractText()
# Out:
# 'Power Measurements on Pulsed Signals1EF48_2E2Rohde & SchwarzContents1Overview.............................................................................................22Requirements......................................................................................23Peak- and Mean Power Measurement..................................................34Performing the Measurements.............................................................5Test Setup......................................................................................5Measurement examples..................................................................5Measurement of peak power and pulse width.............................5Measurement of the mean power...............................................7Measurement of the average and peak power............................9Sources of measurement errors...............................................105Literature.............................................................
# ...

# %% [markdown]
# #### Q1. In what modes should the PdfFileReader() and PdfFileWriter() File objects will be opened?

# %% [markdown]
# + The PdfFileReader file object open in "rb" mode.
#
# mypdf = open("itemlist.pdf","rb")
#
# pdfReader = PyPDF2.pdfFileReadaer(mypdf)
#
# page1  = pdfReader.getPage(0)
#
#
# + The pdfFilWrite object will be open in "wb" mode.
#
# pdftowrite = open("itemlist1.pdf","wb")
#
# pdfwriterobj = PyPDF.pdfWriter()
#
# pdfwriterobj.addpage(page1)
#
# pdftowrite.write(pdftowrite)
#
# pdftowrite.close()
#
# mypdf.close()

# %% [markdown]
# #### 2. From a PdfFileReader object, how do you get a Page object for page 5?

# %%
import PyPDF2
pdfFileObj = open("D:/C_Band_Silkheds_Docs/1EF48_2E.pdf","rb")
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)

# %%
pdfReader.numPages
# Out:
# 12

# %%
pdfReader.getPage(4)
# Out:
# {'/Type': '/Page',
#  '/Parent': {'/Type': '/Pages',
#   '/Count': 12,
#   '/Kids': [IndirectObject(6, 0),
#    IndirectObject(14, 0),
#    IndirectObject(18, 0),
#    IndirectObject(21, 0),
#    IndirectObject(25, 0),
#    IndirectObject(28, 0),
#    IndirectObject(33, 0),
#    IndirectObject(36, 0),
#    IndirectObject(39, 0),
#    IndirectObject(42, 0),
#    IndirectObject(45, 0),
#    IndirectObject(48, 0)]},
#  '/MediaBox': [0, 0, 612, 792],
#  '/Resources': {'/ProcSet': ['/PDF', '/Text'],
#   '/Font': {'/F1': {'/Type': '/Font',
#     '/Subtype': '/TrueType',
#     '/Name': '/F1',
#     '/BaseFont': '/Arial',
#     '/FirstChar': 32,
#     '/LastChar': 255,
#     '/Widths': [278,
#      278,
#      355,
#      556,
#      556,
#      889,
#      667,
#      191,
#      333,
#      333,
#      389,
#      584,
#      278,
#      333,
#      278,
#      278,
#      556,
#      556,
#      556,
#      556,
#      556,
#      556,
#      556,
#      556,
#      556,
#      556,
# ...

# %% [markdown]
# #### 3. What PdfFileReader variable stores the number of pages in the PDF document?

# %%
import PyPDF2
pdfFileObj = open("D:/C_Band_Silkheds_Docs/1EF48_2E.pdf","rb")
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)

# %%
numPages = pdfReader.numPages

# %%
numPages
# Out:
# 12

# %% [markdown]
# numPages variable store the number of pages in pdf

# %% [markdown]
# #### Q4. If a PdfFileReader object’s PDF is encrypted with the password swordfish, what must you do before you can obtain Page objects from it?

# %%
import PyPDF2
pdfFileObj = open("D:/C_Band_Silkheds_Docs/1EF48_2E.pdf","rb")
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
pdfReader.isEncrypted
# Out:
# False

# %% [markdown]
# To test PDF file is encrypted or not pdfReader.isEncrypted method can be used. If result is True it means PDF is encrypted then corrected passward can be used to decrypt PDF document . pdfReader.decrypt("password") used to derypt the file.

# %% [markdown]
# In this question document is encrypted with "swordfish" password so pdfReadae.decrypt("swordfish") method used to decrypt the document.

# %%
import PyPDF2
import os
pdfFileObj = open("D:/C_Band_Silkheds_Docs/1EF48_2E.pdf","rb")
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
print("Is PDF encrypted: %s" %(pdfReader.isEncrypted))
print("Number of pages in PDF document = %s" %(pdfReader.numPages))

fpath = "D:/C_Band_Silkheds_Docs/EncriptedSpectrum.pdf"

#Write pdf
if os.path.exists(fpath):
    os.remove(fpath)
    print("Delete old existing file and then creating new file")
    newPdf = open("D:/C_Band_Silkheds_Docs/EncriptedSpectrum.pdf","wb")
else:
    print("File not exist so creating new file")
    newPdf = open("D:/C_Band_Silkheds_Docs/EncriptedSpectrum.pdf","wb")
pdfWriter = PyPDF2.PdfFileWriter()

#Append pages in pdfRead to pdfWriter one by one
for pageNum in range(pdfReader.numPages):
    pdfWriter.addPage(pdfReader.getPage(pageNum))
    
pdfWriter.encrypt(user_pwd="user",owner_pwd="spectrum")
pdfWriter.write(newPdf)
newPdf.close()
# Out:
# Is PDF encrypted: False
# Number of pages in PDF document = 12
# Delete old existing file and then creating new file

# %%
import os
fpath = "D:/C_Band_Silkheds_Docs/EncriptedSpectrum.pdf"

pdfFileObj = open(fpath,"rb")
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
print("Is PDF encrypted : %s" %(pdfReader.isEncrypted))
print("Number of pages in PDF document = %s" %(pdfReader.numPages))
# Out:
# Is PDF encrypted : True
# ---------------------------------------------------------------------------
# PdfReadError                              Traceback (most recent call last)
# C:\ProgramData\Anaconda3\envs\mldl\lib\site-packages\PyPDF2\pdf.py in getNumPages(self)
#    1147                 self.decrypt('')
# -> 1148                 return self.trailer["/Root"]["/Pages"]["/Count"]
#    1149             except:
#
# C:\ProgramData\Anaconda3\envs\mldl\lib\site-packages\PyPDF2\generic.py in __getitem__(self, key)
#     515     def __getitem__(self, key):
# --> 516         return dict.__getitem__(self, key).getObject()
#     517
#
# C:\ProgramData\Anaconda3\envs\mldl\lib\site-packages\PyPDF2\generic.py in getObject(self)
#     177     def getObject(self):
# --> 178         return self.pdf.getObject(self).getObject()
#     179
#
# C:\ProgramData\Anaconda3\envs\mldl\lib\site-packages\PyPDF2\pdf.py in getObject(self, indirectReference)
# ...

# %%
import os
fpath = "D:/C_Band_Silkheds_Docs/EncriptedSpectrum.pdf"

pdfFileObj = open(fpath,"rb")
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
print("Is PDF encrypted: %s" %(pdfReader.isEncrypted))
if pdfReader.isEncrypted:
    print("please provide decreption passward to access file")
    pdfReader.decrypt("spectrum")
print("Number of pages in PDF document = %s" %(pdfReader.numPages))
# Out:
# Is PDF encrypted: True
# please provide decreption passward to access file
# Number of pages in PDF document = 12

# %% [markdown]
# #### Q5. What methods do you use to rotate a page?

# %%
import PyPDF2
pdfFileObj = open("D:/C_Band_Silkheds_Docs/1EF48_2E.pdf","rb")
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
print("Is PDF encrypted: %s" %(pdfReader.isEncrypted))
print("Number of pages in PDF document = %s" %(pdfReader.numPages))
page = pdfReader.getPage(0) #Read first page in pdf document
page.rotateClockwise(90) # Rotate page 90 degree in clockwise direction
page.rotateCounterClockwise(90) # Rotate page counter clockwise direction with 90 degree
# Out:
# Is PDF encrypted: False
# Number of pages in PDF document = 12
# {'/Type': '/Page',
#  '/Parent': {'/Type': '/Pages',
#   '/Count': 12,
#   '/Kids': [IndirectObject(6, 0),
#    IndirectObject(14, 0),
#    IndirectObject(18, 0),
#    IndirectObject(21, 0),
#    IndirectObject(25, 0),
#    IndirectObject(28, 0),
#    IndirectObject(33, 0),
#    IndirectObject(36, 0),
#    IndirectObject(39, 0),
#    IndirectObject(42, 0),
#    IndirectObject(45, 0),
#    IndirectObject(48, 0)]},
#  '/MediaBox': [0, 0, 612, 792],
#  '/Resources': {'/ProcSet': ['/PDF', '/Text', '/ImageC'],
#   '/Font': {'/F1': {'/Type': '/Font',
#     '/Subtype': '/TrueType',
#     '/Name': '/F1',
#     '/BaseFont': '/Arial',
#     '/FirstChar': 32,
#     '/LastChar': 255,
#     '/Widths': [278,
#      278,
#      355,
#      556,
#      556,
#      889,
#      667,
#      191,
#      333,
#      333,
#      389,
#      584,
#      278,
#      333,
#      278,
#      278,
#      556,
#      556,
#      556,
#      556,
# ...

# %% [markdown]
# #### Q6. What is the difference between a Run object and a Paragraph object?

# %% [markdown]
# __Run object__ : Run object is a contiguous run of the text with same style. A new run object in needed whenever the text style changes.

# %% [markdown]
# __Paragraph object:__  Paragraph objects contains a list of one or more run objects. A new paragraph begins whenever the user press ENTER or RETURN while typing in a Word document.

# %% [markdown]
# #### Q7. How do you obtain a list of Paragraph objects for a Document object that’s stored in a variable named doc?

# %%
import docx

# %%
 doc = docx.Document("Assignment_12.docx")

# %%
#Find length of paragraphs in the document
len(doc.paragraphs)
# Out:
# 13

# %%
doc.paragraphs[0].text
# Out:
# ' 1. In what modes should the PdfFileReader() and PdfFileWriter() File objects will be opened?'

# %%
type(doc.paragraphs)
# Out:
# list

# %%
for para in doc.paragraphs:
    print(para.text)
# Out:
#  1. In what modes should the PdfFileReader() and PdfFileWriter() File objects will be opened?
# 2. From a PdfFileReader object, how do you get a Page object for page 5?
# 3. What PdfFileReader variable stores the number of pages in the PDF document?
# 4. If a PdfFileReader object’s PDF is encrypted with the password swordfish, what must you do before you can obtain Page objects from it?
# 5. What methods do you use to rotate a page?
# 6. What is the difference between a Run object and a Paragraph object?
# 7. How do you obtain a list of Paragraph objects for a Document object that’s stored in a variable named doc?
# 8. What type of object has bold, underline, italic, strike, and outline variables?
# 9. What is the difference between False, True, and None for the bold variable?
# 10. How do you create a Document object for a new Word document?
# 11. How do you add a paragraph with the text 'Hello, there!' to a Document object stored in a variable named doc?
# ...

# %%
# Number of  run objects in paragraphs
len(doc.paragraphs[1].runs)
# Out:
# 7

# %%
for run in doc.paragraphs[0].runs:
    print(run.text)
# Out:
#
# 1. In what modes should the
# PdfFileReader
# () and
# PdfFileWriter
# () File objects will be opened?

# %%
for run in doc.paragraphs[1].runs:
    print(run.text)
# Out:
# 2. From a
# PdfFileReader
#  object,
# how
#  do you get a
# Page
#  object for page 5?

# %%
import docx
def getText(filename):
    """Function used to read text from doc file
    using paragraphs method
    """
    doc = docx.Document(filename)
    para_list = []
    
    for para in doc.paragraphs:
        para_list.append(para.text)
    full_text = "\n".join(para_list)
    return full_text

# %%
text = getText(filename="Assignment_12.docx")

# %%
print(text)
# Out:
#  1. In what modes should the PdfFileReader() and PdfFileWriter() File objects will be opened?
# 2. From a PdfFileReader object, how do you get a Page object for page 5?
# 3. What PdfFileReader variable stores the number of pages in the PDF document?
# 4. If a PdfFileReader object’s PDF is encrypted with the password swordfish, what must you do before you can obtain Page objects from it?
# 5. What methods do you use to rotate a page?
# 6. What is the difference between a Run object and a Paragraph object?
# 7. How do you obtain a list of Paragraph objects for a Document object that’s stored in a variable named doc?
# 8. What type of object has bold, underline, italic, strike, and outline variables?
# 9. What is the difference between False, True, and None for the bold variable?
# 10. How do you create a Document object for a new Word document?
# 11. How do you add a paragraph with the text 'Hello, there!' to a Document object stored in a variable named doc?
# ...

# %% [markdown]
# #### Q8. What type of object has bold, underline, italic, strike, and outline variables?

# %% [markdown]
# A Run object has bold, underline,italic,strike and outline variables.

# %% [markdown]
# #### Q9. What is the difference between False, True, and None for the bold variable?

# %% [markdown]
# + Run object in paragraph  can be further styled using text attributes.Each attribute can be set to one of three values:True (the attribute is always enabled, no matter what other styles are applied to the run),False (the attribute is always disabled),None (defaults to whatever the run’s style is set to)
#
# + True always makes the Run object bolded and False makes it always not bolded, no matter what the style’s bold setting is. None will make the Run object just use the style’s bold setting

# %% [markdown]
# #### Q10. How do you create a Document object for a new Word document?

# %%
import docx
doc = docx.Document() #Create new blank document
doc.add_paragraph("We are creating first document")
doc.save("word_firstdoc.docx")

# %% [markdown]
# #### Q11. How do you add a paragraph with the text 'Hello, there!' to a Document object stored in a variable named doc?

# %%
import docx
doc = docx.Document() #Create new blank document
doc.add_paragraph("We are creating first document")
parObj1 = doc.add_paragraph("Hello there!")
doc.save("word_firstdoc.docx")

# %% [markdown]
# #### Q12. What integers represent the levels of headings available in Word documents?

# %% [markdown]
# + The arguments to add_heading() are a string of the heading text and an integer from 0 to 4.
# + The integer 0 makes the heading the Title style, which is used for the top of the document.
# + Integers 1 to 4 are for various heading levels, with 1 being the main heading and 4 the lowest subheading.

# %%
import docx
doc = docx.Document() #Create new blank document
doc.add_heading("This is main heading 0",0)
doc.add_heading("This is an second heading 1",1)

doc.add_paragraph("We are creating first document")
parObj1 = doc.add_paragraph("Hello there!")
doc.save("word_firstdoc.docx")
