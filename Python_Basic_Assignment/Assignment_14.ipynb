# %% [markdown]
# #### Q1. What does RGBA stand for?

# %% [markdown]
# + RGB stand for basic color vlaues of Red, Green and Blue  and A refers to alpha that is transparency in the color value.
# + RGBA values are assigned to individual pixel and pixel is the smallest dot of a single color in the image.
# + A pixel’s RGB setting tells it precisely what shade of color it should display.

# %% [markdown]
# #### Q2. From the Pillow module, how do you get the RGBA value of any images?

# %%
from PIL import Image
from PIL import ImageColor

# %%
catIm = Image.open("Zophie.png")

# %%
catIm
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=319x426 at 0x292071AC310>

# %%
catIm.size #Get image pixels width and height
# Out:
# (319, 426)

# %%
catIm.get
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19676/2592590938.py in <module>
# ----> 1 catIm.get
#
# C:\ProgramData\Anaconda3\envs\mldl\lib\site-packages\PIL\Image.py in __getattr__(self, name)
#     544             )
#     545             return self._category
# --> 546         raise AttributeError(name)
#     547
#     548     @property
#
# AttributeError: get

# %%
rgba = catIm.convert("RGBA")

# %%
type(rgba)

# %%
rgbadata = rgba.getdata()

# %%
type(rgbadata)

# %%
rgbadata

# %%
for item in rgbadata:
    print(item)

# %% [markdown]
# #### Q3. What is a box tuple, and how does it work?

# %% [markdown]
# + Tuple box is a tuple of four integer coordinates that represent a rectangular region in an image. e.g (Left,Top,Right,Bottom)
# + Left: The x-coordinate of the left most edge of the box.
# + Top: The y-coordinate of the top edge of the box.
# + Right: The x-coordinate of one pixel to the right of the rightmost edge of the box. This integer must be greater than the the top integer.
# + Bottom: The y-coordinate of the one pixel lower than the bottom edge of the box. This integer must be greater than the top integer.

# %%
from PIL import Image, ImageColor

# %%
catIm = Image.open("Zophie.png")
catIm.size

# %%
croppedIm = catIm.crop((100,140,251,251)) # LTRB

# %%
croppedIm

# %%
croppedIm.save("cropped.png")

# %% [markdown]
# #### Q4. Use your image and load in notebook then, How can you find out the width and height of an Image object?

# %%
from PIL import Image, ImageColor
catIm = Image.open("Zophie.png")
width, height = catIm.size
print("Width = %s, Height = %s" %(width,height))

# %% [markdown]
# #### Q5. What method would you call to get Image object for a 100×100 image, excluding the lower-left quarter of it?

# %%
from PIL import Image, ImageColor
catIm = Image.open("Zophie.png")
crop = catIm.crop(box=(0,0,101,101))

# %%
crop.size

# %%
crop

# %% [markdown]
# #### Q6. After making changes to an Image object, how could you save it as an image file?

# %%
from PIL import Image, ImageColor
catIm = Image.open("Zophie.png")
croppedIm = catIm.crop(box=(0,0,101,101))
croppedIm.save("cropped101.png")

# %% [markdown]
# #### Q7. What module contains Pillow’s shape-drawing code?

# %% [markdown]
# + ImageDraw module in Pillow's package used draw points,lines, rectangles,ellipses and polygons on image.

# %% [markdown]
# #### Q8. Image objects do not have drawing methods. What kind of object does? How do you get this kind of object?
